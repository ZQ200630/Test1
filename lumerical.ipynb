# %%
import imp
# Out:
# C:\Users\Jason\AppData\Local\Temp\ipykernel_7128\713651319.py:1: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp

# %%
# Load the lumerical module

lumapi = imp.load_source('lumapi', 'D:\\Software\\Ansys Lumerical\\api\\python\\lumapi.py')

# %%
# Open a new FDTD session

fdtd = lumapi.FDTD()

# %%
# Close the session

# del(fdtd)
fdtd.close()

# %%
# Open a new FDTD session with a file

# fdtd = lumapi.FDTD(filename="file.fsp")
# fdtd.close()

# Open a new FDTD session with a file in the background
# fdtd = lumapi.FDTD(filename="file.fsp", hide=True)
# fdtd.close()

fdtd = lumapi.FDTD(filename="C:\\Users\\Jason\\Documents\\Lumerical\\MyProject\\Sim1\\Test.fsp")

# %%
# Start a new FDTD session with a file_read version

with lumapi.FDTD(filename="file.fsp", readonly=True) as fdtd:
    # do stuff
    pass

# %%
# Show ALL Api commands
dir(fdtd)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'abs',
#  'acos',
#  'add2dpoly',
#  'add2drect',
#  'add2visualizer',
#  'addanalysisgroup',
#  'addanalysisprop',
#  'addanalysisresult',
#  'addattribute',
#  'addcircle',
#  'addcustom',
#  'adddipole',
#  'addfdtd',
#  'addgaussian',
#  'addgridattribute',
#  'addgroup',
#  'addimport',
#  'addimportedsource',
#  'addindex',
#  'addjob',
#  'addlayer',
#  'addlayerbuilder',
#  'addmaterial',
#  'addmesh',
#  'addmode',
#  'addmodeexpansion',
#  'addmovie',
#  'addobject',
#  'addparameter',
#  'addpath',
# ...

# %%
# Show All Attributes of the fdtd object by name
with lumapi.FDTD(filename="C:\\Users\\Jason\\Documents\\Lumerical\\MyProject\\Sim1\\Test.fsp", hide=True) as fdtd:
    print(fdtd.getnamed("Substrate"))
# Out:
# alpha
# color opacity
# detail
# enabled
# first axis
# grid attribute name
# index
# index units
# material
# mesh order
# name
# override color opacity from material database
# override mesh order from material database
# render type
# rotation 1
# rotation 2
# rotation 3
# second axis
# set color opacity from material database
# set mesh order from material database
# third axis
# type
# use relative coordinates
# x
# x max
# x min
# x span
# y
# y max
# y min
# y span
# z
# z max
# z min
# z span

# %%
# Show the help message of the command
help(fdtd.getnamed)
# Out:
# Help on method getnamed in module lumapi:
#
# getnamed(*args) method of lumapi.FDTD instance
#     Gets a property from objects with a given name.
#
#     If multiple objects are selected, and the values are different, the
#     smallest value is returned. To be certain of the results, be sure that
#     only one object is selected, or use the form of getnamed that allows a
#     specific object to be selected.
#
#     +--------------------------------------+--------------------------------------+
#     | Syntax                               | Description                          |
#     +--------------------------------------+--------------------------------------+
#     | print o.getnamed("name")             | Returns a list of the properties of  |
#     |                                      | the objects called name.             |
#     +--------------------------------------+--------------------------------------+
# ...
